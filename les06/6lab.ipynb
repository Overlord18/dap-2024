# %%
#1 Выведете описание набора данных и наименование признаков.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
diabetes = datasets.load_diabetes()
print(diabetes.DESCR)
print(diabetes.feature_names)
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
# :Number of Instances: 442
#
# :Number of Attributes: First 10 columns are numeric predictive values
#
# :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
# :Attribute Information:
#     - age     age in years
#     - sex
#     - bmi     body mass index
#     - bp      average blood pressure
#     - s1      tc, total serum cholesterol
#     - s2      ldl, low-density lipoproteins
#     - s3      hdl, high-density lipoproteins
#     - s4      tch, total cholesterol / HDL
#     - s5      ltg, possibly log of serum triglycerides level
# ...

# %%
# Из загруженного набора данных создайте DataFrame, содержащий как признаки, так и целевое значение. Выведите первые 5 строк набора.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
diabetes = datasets.load_diabetes()
print(diabetes.DESCR)
print(diabetes.feature_names)
diabetes_df = pd.DataFrame(data = diabetes.data, columns = diabetes.feature_names)
diabetes_df['target'] = diabetes.target
diabetes_df.head(5)
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
# :Number of Instances: 442
#
# :Number of Attributes: First 10 columns are numeric predictive values
#
# :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
# :Attribute Information:
#     - age     age in years
#     - sex
#     - bmi     body mass index
#     - bp      average blood pressure
#     - s1      tc, total serum cholesterol
#     - s2      ldl, low-density lipoproteins
#     - s3      hdl, high-density lipoproteins
#     - s4      tch, total cholesterol / HDL
#     - s5      ltg, possibly log of serum triglycerides level
# ...

# %%
# Выведете информацию о типах данных в наборе. Имеются ли в наборе категориальные признаки? Имеются ли в наборе данные имеющие значение null?
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_diabetes
diabetes = load_diabetes()
diabetes_df.info()
print("Категориальные признаки:, diabetes_df.select_dtypes(include='object').columns)")
print("Пропущенные значения (количество в каждом столбце)"),
print(diabetes_df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     442 non-null    float64
#  1   sex     442 non-null    float64
#  2   bmi     442 non-null    float64
#  3   bp      442 non-null    float64
#  4   s1      442 non-null    float64
#  5   s2      442 non-null    float64
#  6   s3      442 non-null    float64
#  7   s4      442 non-null    float64
#  8   s5      442 non-null    float64
#  9   s6      442 non-null    float64
#  10  target  442 non-null    float64
# dtypes: float64(11)
# memory usage: 38.1 KB
# Категориальные признаки:, diabetes_df.select_dtypes(include='object').columns)
# Пропущенные значения (количество в каждом столбце)
# age       0
# sex       0
# bmi       0
# bp        0
# s1        0
# s2        0
# s3        0
# s4        0
# s5        0
# s6        0
# target    0
# dtype: int64

# %%
#4 Постройте матрицу корреляции.
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_diabetes
diabetes = load_diabetes()
diabetes_df.corr()
correlation_matrix = diabetes_df.corr()

# Шаг 2: Постройте теплую карту с помощью Seaborn
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")

# Названия осей и заголовок
plt.title("Матрица корреляции")
plt.show()

# %%
#5 Постройте диаграмму рассеяния целевого значение и признака, коэффициент корреляции которого с целевым значением, самый высокий.
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_diabetes
diabetes = load_diabetes()
max_corr_feature = diabetes_df.corr()['target'].drop('target').idxmax()
# Признак с наибольшей корреляцией с целевым значением\n",
sns.scatterplot(x = diabetes_df[max_corr_feature], y = diabetes_df['target'])
plt.show()

# %%
#6 Сформируйте набор признаков (X) из 5 признаков с самым высоким коэффициентом корреляции с целевым значением. Сформируйте набор для целевого значения (y).
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_diabetes
diabetes = load_diabetes()
correlation = diabetes_df.corr()['target']
top_5_features = correlation.abs().sort_values(ascending=False).index[1:6]
X = diabetes_df[top_5_features]
y = diabetes_df['target']
print(X, y)
# Out:
#           bmi        s5        bp        s4        s3
# 0    0.061696  0.019907  0.021872 -0.002592 -0.043401
# 1   -0.051474 -0.068332 -0.026328 -0.039493  0.074412
# 2    0.044451  0.002861 -0.005670 -0.002592 -0.032356
# 3   -0.011595  0.022688 -0.036656  0.034309 -0.036038
# 4   -0.036385 -0.031988  0.021872 -0.002592  0.008142
# ..        ...       ...       ...       ...       ...
# 437  0.019662  0.031193  0.059744 -0.002592 -0.028674
# 438 -0.015906 -0.018114 -0.067642  0.034309 -0.028674
# 439 -0.015906 -0.046883  0.017293 -0.011080 -0.024993
# 440  0.039062  0.044529  0.001215  0.026560 -0.028674
# 441 -0.073030 -0.004222 -0.081413 -0.039493  0.173816
#
# [442 rows x 5 columns] 0      151.0
# 1       75.0
# 2      141.0
# 3      206.0
# 4      135.0
#        ...
# 437    178.0
# 438    104.0
# 439    132.0
# 440    220.0
# 441     57.0
# Name: target, Length: 442, dtype: float64

# %%
#7
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn import datasets
from sklearn.model_selection import train_test_split
diabetes = datasets.load_diabetes()
df = pd.DataFrame(data=diabetes.data, columns=diabetes.feature_names)
df['target'] = diabetes.target
correlations = df.corr()['target'].drop('target')
top_5_features = correlations.abs().sort_values(ascending=False).head(5).index.tolist()
X = df[top_5_features]
y = df['target']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
print("Размер обучающего набора:", X_train.shape)
print("Размер тестового набора:", X_test.shape)
# Out:
# Размер обучающего набора: (331, 5)
# Размер тестового набора: (111, 5)

# %%
#8
import pandas as pd
from sklearn import datasets
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
diabetes = datasets.load_diabetes()
df = pd.DataFrame(data=diabetes.data, columns=diabetes.feature_names)
df['target'] = diabetes.target
correlations = df.corr()['target'].drop('target')
top_5_features = correlations.abs().sort_values(ascending=False).head(5).index.tolist()
X = df[top_5_features]
y = df['target']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
model = LinearRegression()
model.fit(X_train, y_train)
print("Коэффициенты модели:", model.coef_)
# Out:
# Коэффициенты модели: [ 583.87411656  456.07465993  331.78536014 -166.13810499 -358.64107422]

# %%
#"Задача №9. Расчитайте Root mean squared error (RMSE)"
import pandas as pd
from sklearn import datasets
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import numpy as np
diabetes = datasets.load_diabetes()
df = pd.DataFrame(data=diabetes.data, columns=diabetes.feature_names)
df['target'] = diabetes.target
correlations = df.corr()['target'].drop('target')
top_5_features = correlations.abs().sort_values(ascending=False).head(5).index.tolist()
X = df[top_5_features]
y = df['target']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print(f"RMSE: {rmse:.2f}")
# Out:
# RMSE: 53.78

# %%
#Задача №10. Расчитайте R² (коэффициент детерминации)
import pandas as pd
from sklearn import datasets
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import numpy as np
diabetes = datasets.load_diabetes()
df = pd.DataFrame(data=diabetes.data, columns=diabetes.feature_names)
df['target'] = diabetes.target
correlations = df.corr()['target'].drop('target')
top_5_features = correlations.abs().sort_values(ascending=False).head(5).index.tolist()
X = df[top_5_features]
y = df['target']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
r2 = r2_score(y_test, y_pred)
print(f"Коэффициент детерминации R²: {r2:.2f}")
# Out:
# Коэффициент детерминации R²: 0.48

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-529510172.py in <cell line: 0>()
#       4 import matplotlib.pyplot as plt
#       5 from sklearn import metrics
# ----> 6 print('R2 = ', np.sqrt(metrics.r2_score(y_test, y_pred)))
#
# NameError: name 'y_test' is not defined
